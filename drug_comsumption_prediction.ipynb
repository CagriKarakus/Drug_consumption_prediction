# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Model
from sklearn.linear_model import RidgeClassifier

# Bayesçi hiperparametre araması
from skopt import BayesSearchCV

# -------------------------------------------------------
# 1) Veri Yükleme ve Kolon İsimlerinin Belirlenmesi
# -------------------------------------------------------
column_names = [
    "ID", "Age", "Gender", "Education", "Country", "Ethnicity",
    "Nscore", "Escore", "Oscore", "Ascore", "Cscore",
    "Impulsive", "SS",
    "Alcohol", "Amphet", "Amyl", "Benzos", "Caff",
    "Cannabis", "Choc", "Coke", "Crack", "Ecstasy",
    "Heroin", "Ketamine", "Legalh", "LSD", "Meth",
    "Mushrooms", "Nicotine", "Semer", "VSA"
]

data = pd.read_csv('/content/drug_consumption.data', header=None, names=column_names)

# -------------------------------------------------------
# 2) Özelliklerin (Features) Seçilmesi ve Kodlama/Ölçeklendirme
# -------------------------------------------------------
X = data[[
    "Age", "Gender", "Education", "Country", "Ethnicity",
    "Nscore", "Escore", "Oscore", "Ascore", "Cscore",
    "Impulsive", "SS"
]]
substance_columns = column_names[13:]  # 13. kolondan sonraki tüm sütunlar

# Kullanım seviyelerini 3 sınıfa indirgeme (örnek kodlama)
for col in substance_columns:
    data[col] = data[col].replace({
        'CL0': 0, 'CL1': 1,           # Düşük kullanım
        'CL2': 2, 'CL3': 3, 'CL4': 4, # Orta kullanım
        'CL5': 5, 'CL6': 6            # Yüksek kullanım
    })

# Özellikleri ölçeklendirme
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# -------------------------------------------------------
# 3) Bayesçi Arama İçin Hiperparametre Alanı
# -------------------------------------------------------
# RidgeClassifier -> alpha parametresini log-uniform aralıkta arayacağız (1e-5 ~ 1e3)
search_spaces = {
    'alpha': (1e-5, 1e3, 'log-uniform')
}

# -------------------------------------------------------
# 4) Her Madde İçin RidgeClassifier + Bayesian Optimization
# -------------------------------------------------------
for substance in substance_columns:
    print(f"\n===== Substance: {substance} =====")

    y = data[substance]

    # Kategorik değerleri sayısala çevir
    y_encoded, y_classes = pd.factorize(y)

    # Eğitim ve test setlerine ayırma
    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y_encoded,
        test_size=0.3,
        random_state=42
    )

    # BayesSearchCV ile RidgeClassifier
    # n_iter: kaç farklı hiperparametre deneneceği
    bayes_search = BayesSearchCV(
        estimator=RidgeClassifier(),
        search_spaces=search_spaces,
        n_iter=32,               # Daha fazla arttırırsanız daha iyi sonuçlar bulabilir (zamana bağlı)
        cv=5,                    # 5 katlı çapraz doğrulama
        scoring='accuracy',
        n_jobs=-1,               # Tüm CPU çekirdeklerini kullan
        random_state=42
    )

    bayes_search.fit(X_train, y_train)
    best_model = bayes_search.best_estimator_
    best_alpha = bayes_search.best_params_['alpha']

    print(f"Best alpha (BayesSearch): {best_alpha:.4f}")

    # Modeli test setinde değerlendirme
    y_pred = best_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy (Doğruluk): {accuracy:.3f}")

    # Yalnızca test setinde var olan sınıfları bulalım
    unique_label_indices = np.unique(y_test)

    # Classification Report
    report = classification_report(
        y_test,
        y_pred,
        labels=unique_label_indices,
        target_names=[str(y_classes[i]) for i in unique_label_indices],
        zero_division=0
    )
    print("Classification Report:")
    print(report)

    # ----------------------------------------------------
    # 4.1) Confusion Matrix (Karmaşıklık Matrisi) Grafiği
    # ----------------------------------------------------
    cm = confusion_matrix(y_test, y_pred, labels=unique_label_indices)
    plt.figure(figsize=(7, 5))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=[str(y_classes[i]) for i in unique_label_indices],
        yticklabels=[str(y_classes[i]) for i in unique_label_indices]
    )
    plt.title(f"Confusion Matrix - {substance}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------
    # 4.2) Özellik Katsayıları Bar Grafiği
    # ----------------------------------------------------
    # RidgeClassifier'ın katmanları (coef_) bir matriste saklanır
    # İlk satır, "0" sınıfı ile ilgili katsayıları temsil eder (binary senaryoda)
    # 3 sınıfınız varsa shape (3, n_features) olabilir.
    # Bu kod, illüstratif olarak ilk satırı (0. index) gösteriyor.
    coefficients = best_model.coef_[0]

    plt.figure(figsize=(12, 5))
    plt.bar(X.columns, coefficients, color='skyblue', edgecolor='black')
    plt.title(f'Feature Influence on {substance} (Accuracy: {accuracy:.3f}, alpha={best_alpha:.4f})', fontsize=14)
    plt.xlabel('Features', fontsize=12)
    plt.ylabel('Coefficient Value', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------
    # 4.3) Classification Report'un Bar Grafikleri
    # ----------------------------------------------------
    # Raporu sözlük formatına çevirip DataFrame'e dönüştürelim
    report_dict = classification_report(
        y_test,
        y_pred,
        labels=unique_label_indices,
        target_names=[str(y_classes[i]) for i in unique_label_indices],
        zero_division=0,
        output_dict=True
    )
    df_report = pd.DataFrame(report_dict).transpose()

    # "accuracy", "macro avg", "weighted avg" vb. hariç tutarak, sadece sınıfları alacağız
    df_class_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg'], errors='ignore')

    metrics_to_plot = ['precision', 'recall', 'f1-score']
    plt.figure(figsize=(8, 5))
    df_class_report[metrics_to_plot].plot(kind='bar')
    plt.title(f'{substance} - Precision, Recall, F1-Score by Class', fontsize=14)
    plt.xlabel('Classes', fontsize=12)
    plt.ylabel('Score', fontsize=12)
    plt.xticks(rotation=0)
    plt.ylim([0, 1])
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.show()

    # Support grafiği
    plt.figure(figsize=(6, 4))
    df_class_report[['support']].plot(kind='bar', legend=False)
    plt.title(f'{substance} - Support (Num of Samples by Class)', fontsize=14)
    plt.xlabel('Classes', fontsize=12)
    plt.ylabel('Support Count', fontsize=12)
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()

    print("\n")  # Konsolda ayrım için boşluk
# Out:
# <ipython-input-3-34269a9d1b91>:44: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[col] = data[col].replace({
# ===== Substance: Alcohol =====
# Best alpha (BayesSearch): 50.0158
# Accuracy (Doğruluk): 0.413
# Classification Report:
#               precision    recall  f1-score   support
#
#            5       0.42      0.88      0.57       229
#            6       0.37      0.21      0.27       135
#            4       0.50      0.02      0.04        96
#            2       0.00      0.00      0.00        24
#            1       0.00      0.00      0.00        11
#            0       0.00      0.00      0.00        11
#            3       0.33      0.02      0.03        60
#
#     accuracy                           0.41       566
# ...
